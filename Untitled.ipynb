# %%
import pandas as pd
import numpy as np

# %%
# Load the dataset
df = pd.read_csv('archive/BTC-2021min.csv')

# %%
# Display the first 5 rows to inspect the data
print(df.head())
# Out:
#          unix                 date   symbol      open      high       low  \
# 0  1646106180  2022-03-01 03:43:00  BTC/USD  43046.58  43046.58  43046.58
# 1  1646106060  2022-03-01 03:41:00  BTC/USD  43018.23  43046.59  43018.23
# 2  1646106000  2022-03-01 03:40:00  BTC/USD  43022.24  43022.24  43016.03
# 3  1646105940  2022-03-01 03:39:00  BTC/USD  43035.16  43035.16  42999.44
# 4  1646105880  2022-03-01 03:38:00  BTC/USD  43077.82  43077.82  43049.46
#
#       close  Volume BTC    Volume USD
# 0  43046.58    0.000000      0.000000
# 1  43046.58    0.142977   6154.673021
# 2  43016.03    0.009230    397.037957
# 3  42999.44    0.820950  35300.390268
# 4  43049.46    0.022210    956.143143

# %%
# Convert the 'Date' column to datetime objects
df['date'] = pd.to_datetime(df['date'])
# Set the 'Date' column as the index
df.set_index('date', inplace=True)
# Sort the index to ensure the data is in chronological order
df.sort_index(inplace=True)
# Check the data types and look for missing values
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 610782 entries, 2021-01-01 00:01:00 to 2022-03-01 03:43:00
# Data columns (total 8 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   unix        610782 non-null  int64
#  1   symbol      610782 non-null  object
#  2   open        610782 non-null  float64
#  3   high        610782 non-null  float64
#  4   low         610782 non-null  float64
#  5   close       610782 non-null  float64
#  6   Volume BTC  610782 non-null  float64
#  7   Volume USD  610782 non-null  float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 41.9+ MB
# None

# %%
# Create the target variable
df["Tomorrow_Close"] = df["close"].shift(-1)
df["Target"] = (df["Tomorrow_Close"] > df["close"]).astype(int)
# Display the new columns
print(df[["close", "Tomorrow_Close", "Target"]].head())
# Out:
#                         close  Tomorrow_Close  Target
# date
# 2021-01-01 00:01:00  29083.47        29035.89       0
# 2021-01-01 00:02:00  29035.89        29048.13       1
# 2021-01-01 00:03:00  29048.13        29045.19       0
# 2021-01-01 00:04:00  29045.19        28999.50       0
# 2021-01-01 00:05:00  28999.50        28997.36       0

# %%
# Create lag features
for i in range(1, 6):
    df[f"Lag_{i}"] = df["close"].shift(i)
# Drop rows with missing values (the first 5 rows will have NaN for lags)
df.dropna(inplace=True)
# Display the new lag features
print(df.head())
# Out:
#                            unix   symbol      open      high       low  \
# date
# 2021-01-01 00:06:00  1609459560  BTC/USD  28996.71  29025.68  28996.71
# 2021-01-01 00:07:00  1609459620  BTC/USD  29000.96  29012.16  28983.04
# 2021-01-01 00:08:00  1609459680  BTC/USD  28993.53  28993.53  28938.21
# 2021-01-01 00:09:00  1609459740  BTC/USD  28945.20  28987.85  28910.15
# 2021-01-01 00:10:00  1609459800  BTC/USD  28932.99  28945.01  28903.28
#
#                         close  Volume BTC    Volume USD  Tomorrow_Close  \
# date
# 2021-01-01 00:06:00  28997.36    1.863222  54028.515034        28990.35
# 2021-01-01 00:07:00  28990.35    1.401503  40630.056408        28941.55
# 2021-01-01 00:08:00  28941.55    2.270325  65706.713217        28937.66
# 2021-01-01 00:09:00  28937.66    2.372179  68645.315438        28925.13
# 2021-01-01 00:10:00  28925.13    1.468206  42468.061276        28888.34
#
#                      Target     Lag_1     Lag_2     Lag_3     Lag_4     Lag_5
# date
# ...

# %%
# Define the feature columns
features = [f'Lag_{i}' for i in range(1, 6)]
# Define X and y
X = df[features]
y = df['Target']

# %%
# Define the split point
split_percentage = 0.8
split_point = int(len(X) * split_percentage)
# Split the data
X_train = X[:split_point]
y_train = y[:split_point]
X_test = X[split_point:]
y_test = y[split_point:]
# Verify the shapes of the splits
print(f"X_train shape: {X_train.shape}")
print(f"X_test shape: {X_test.shape}")
# Out:
# X_train shape: (488620, 5)
# X_test shape: (122156, 5)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
# Initialize the models
log_reg = LogisticRegression(max_iter=200) #max no of iteration problem solved 
rand_forest = RandomForestClassifier(n_estimators=100, random_state=42) #Using 100 trees
# Train the models
log_reg.fit(X_train, y_train)
rand_forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# modelleri Kaydetme işlemi
import joblib

joblib.dump(log_reg, 'logistic_regression_model.pkl')  # Logistic Regression modelini kaydet
joblib.dump(rand_forest, 'random_forest_model.pkl')  # Random Forest modelini kaydet
# Out:
# ['random_forest_model.pkl']

# %%
# Kaydedilen modelleri yükleyin
log_reg = joblib.load('logistic_regression_model.pkl')
rand_forest = joblib.load('random_forest_model.pkl')

# %%
# Make predictions
log_reg_preds = log_reg.predict(X_test)
rand_forest_preds = rand_forest.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
# Evaluate Logistic Regression
print("--- Logistic Regression Performance ---")
print(f"Accuracy: {accuracy_score(y_test, log_reg_preds):.4f}")
print(classification_report(y_test, log_reg_preds))
# Evaluate Random Forest
print("\n--- Random Forest Performance ---")
print(f"Accuracy: {accuracy_score(y_test, rand_forest_preds):.4f}")
print(classification_report(y_test, rand_forest_preds))
# Visualize the Confusion Matrix for the better model (usually Random Forest)
cm = confusion_matrix(y_test, rand_forest_preds)
sns.heatmap(cm, annot=True, fmt="d")
plt.title("Confusion Matrix - Random Forest")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
# Out:
# --- Logistic Regression Performance ---
# Accuracy: 0.5135
#               precision    recall  f1-score   support
#
#            0       0.51      0.87      0.65     62361
#            1       0.51      0.14      0.22     59795
#
#     accuracy                           0.51    122156
#    macro avg       0.51      0.51      0.43    122156
# weighted avg       0.51      0.51      0.44    122156
#
#
# --- Random Forest Performance ---
# Accuracy: 0.5017
#               precision    recall  f1-score   support
#
#            0       0.51      0.53      0.52     62361
#            1       0.49      0.48      0.48     59795
#
#     accuracy                           0.50    122156
#    macro avg       0.50      0.50      0.50    122156
# weighted avg       0.50      0.50      0.50    122156
